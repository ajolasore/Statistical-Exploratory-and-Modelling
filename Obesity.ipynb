# %% [markdown]
# ## Estimation of the Obesity Levels Based on Eating Habits And Physical Condition.
#
#
# #### by
# ### Adeyemi Joshua Olasore

# %% [markdown]
# ### Introduction
#
#
# #### Background
#
# The epidemic of obesity is nothing new. It has existed for centuries. The startling increase in frequency during the past few decades is the most recent development. Across the past half century, it has spread all over the globe. Countries that have been known for their low obesity rates are now seeing increases; China's rate of obesity rise has doubled in the last decade.
#
# The CDC claims that this has an impact on a country's health, economy, and military preparedness. One in three adults is overweight, putting them at increased risk for cardiovascular disease, type 2 diabetes, and several cancers.
# The problem of obesity, sadly, is not restricted to adults. In the United States, 17% of kids and teens are overweight. Despite this being far greater than in previous years, the rate does appear to be worsening. However, the risk for diabetes in children is increased by a factor of four, and children who are fat are more likely to remain obese into adulthood.
#
# The changes in our environment and way of life have occurred at the same time that obesity rates have risen. Many of our once-manual labours are now performed by machines, our diets and the methods by which they are produced have evolved, and our communities are organized to favour the private automobile over other forms of transportation.
#
# Obesity has become a worldwide epidemic, and if we want to stop it, we need to find ways to treat its underlying causes. Predicting the possibility of obesity based on some accessible and quantitative parameters is intriguing to me as an aspiring data scientist.

# %% [markdown]
# #### Research Questions
#
# Furthermore, in order to arrive a sizable conclusion, this research would like to answer the following questions;
#
# •	What is the relationship between various eating habits and Obesity?
#
# •	What is the relationship between various physical conditions and Obesity?
#
# •	What are the significant differences in obesity observed among gender, smokers, connection to family history, etc.?
#
# •	Can Obesity in terms of Body Mass Index (BMI) be predicted given selected parameters?

# %% [markdown]
# #### Objectives
#
# 1.	To determine and visualize the relationship between eating habit, physical condition of people and their corresponding body mass index.
#
# 2.	To evaluate the effect of the categorical parameters on the body mass index using the different correlation tests.
#
# 3.	To determine whether the obtained numerical and categorical parameters predicts obesity in terms of body mass index using regression model.

# %% [markdown]
# ### Methodology
#
# #### Data Collection and Source
#
# The data gives the estimation of obesity levels in people from the countries of Mexico, Peru and Colombia, with ages between 14 and 61 and diverse eating habits and physical condition. According to UCI, the data was primarily collected using a web platform with a survey where anonymous users answered each question, then the information was processed obtaining 17 attributes and 2111 records. These raw data and related information was obtained from the Center for Machine Learning and Intelligent System,  University of California, Irvine (UCI) Machine Learning Repository.

# %% [markdown]
# #### Data Introduction
#
# The dataset includes eating habits attributes such as: Frequent consumption of high caloric food (FAVC), Frequency of consumption of vegetables (FCVC), Number of main meals (NCP), Consumption of food between meals (CAEC), Consumption of water daily (CH20), and Consumption of alcohol (CALC), as well as physical condition attributes such as: Calories consumption monitoring (SCC), Physical activity frequency (FAF), Time using technology (TUE), Means of Transportation (MTRANS). Furthermore, based on Equation (1) and information from WHO and Mexican Normativity, the class variable NObeyesdad was established with the values: Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II, and Obesity Type III. Because the data comprises both numerical and continuous data, it may be analyzed using classification and prediction algorithms.

# %% [markdown]
# #### Data Preparation and Preprocessing
#
# The data was imported into the IDE using the numpy and  pandas library for the needed wrangling and cleaning. Although basic preprocessing has been primarily done on the dataset, there was need to further check for some discrepancies.
# Some of the task involved checking for missing data (is.null()), confirming of the data types (.info()), removal of unessential variables (.drop()), renaming of column names of attributes (.rename()), confirming the values of the categorical variables (.unique()), the determination of the Body Mass Index (BMI) which is the numerical dependent variable needed for the analysis, and finally evaluating the descriptive statistical summary for the measure of central tendency and visible outliers (.describe()).

# %% [markdown]
# #### Data Preparation and Preprocessing Result

# %%
import numpy as np 
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\olaso'

# %%
obesity = pd.read_csv("C:\\Users\\olaso\\OneDrive\\Desktop\\New folder\\ObesityDataSet_raw_and_data_sinthetic (2)\\ObesityDataSet_raw_and_data_sinthetic.csv")

# %%
obesity
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
obesity['BMI'] = obesity['Weight']/(obesity['Height']*obesity['Height'])

# %%
obesity.rename(columns ={'NObeyesdad': 'NObesity'}, inplace =True)

# %%
obesity
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS             NObesity        BMI
# 0             no  Public_Transportation        Normal_Weight  24.386526
# 1      Sometimes  Public_Transportation        Normal_Weight  24.238227
# 2     Frequently  Public_Transportation        Normal_Weight  23.765432
# 3     Frequently                Walking   Overweight_Level_I  26.851852
# 4      Sometimes  Public_Transportation  Overweight_Level_II  28.342381
# ...          ...                    ...                  ...        ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III  44.901475
# 2107   Sometimes  Public_Transportation     Obesity_Type_III  43.741923
# 2108   Sometimes  Public_Transportation     Obesity_Type_III  43.543817
# 2109   Sometimes  Public_Transportation     Obesity_Type_III  44.071535
# 2110   Sometimes  Public_Transportation     Obesity_Type_III  44.144338
#
# [2111 rows x 18 columns]

# %%
obesity.describe().to_excel('description.xlsx')

# %%
obesity.to_excel('obesitydata.xlsx')

# %%
obesity.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObesity                          0
# BMI                               0
# dtype: int64

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObesity                        2111 non-null   object
#  17  BMI                             2111 non-null   float64
# dtypes: float64(9), object(9)
# memory usage: 297.0+ KB

# %%
obesity.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObesity', 'BMI'],
#       dtype='object')

# %% [markdown]
# ##### Variable Names
#
#
# * Eating Habit: Frequent consumption of high caloric food (FAVC),
#
# * Frequency of consumption of vegetables(FCVC)
#
# * Number of main meals (NCP)
#
# * Consumption of food between meals (CAEC)
#
# * Consumption of water daily (CH20)
#
# * Consumption of alcohol (CALC)
#
# *  Calories consumption monitoring (SCC)
#
# * Physical activity frequency (FAF)
#
# * Time using technology devices (TUE)
#
# * Transportation used (MTRANS)

# %%
obesity['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
obesity['FAVC'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
obesity['CAEC'].unique()
# Out:
# array(['Sometimes', 'Frequently', 'Always', 'no'], dtype=object)

# %%
, 'SCC', 'CALC', 'MTRANS', 'NObeyesdad'
# Out:
# ("'SCC',", "'CALC',", "'MTRANS',", "'NObeyesdad'")

# %%
obesity['SCC'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
obesity['CALC'].unique()
# Out:
# array(['no', 'Sometimes', 'Frequently', 'Always'], dtype=object)

# %%
obesity['MTRANS'].unique()
# Out:
# array(['Public_Transportation', 'Walking', 'Automobile', 'Motorbike',
#        'Bike'], dtype=object)

# %%
obesity['NObesity'].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %% [markdown]
# ### Data Analysis tools
#
# #### Exploratory Data Analysis
#
# In order to execute full exploratory analysis of the dataset the matplotlib.pyplot  and seaborn libraries were imported.
#
# Univariate analysis were carried out using the frequency distribution plots, histplot, barplot and countplots. This helps to get summary of selected categorical variables and check for patterns in the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Exploratory Data Analysis Result

# %%
sns.heatmap(obesity.isnull(), cbar =False, cmap = "coolwarm", yticklabels = False);
plt.title('The Check for Missing Value', fontweight = 'bold');

# %%
sns.set_palette('gnuplot_r')
sns.set_style('whitegrid')

# %%
#Age distribution

plt.figure(figsize = (8,6))
sns.histplot(obesity['Age'], kde = True)
plt.title('Distribution plot of Ages', fontweight = 'bold');

# %%
obesity.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE          BMI
# count  2111.000000  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866    29.700159
# std       0.612953     0.850592     0.608927     8.011337
# min       1.000000     0.000000     0.000000    12.998685
# 25%       1.584812     0.124505     0.000000    24.325802
# 50%       2.000000     1.000000     0.625350    28.719089
# 75%       2.477420     1.666678     1.000000    36.016501
# max       3.000000     3.000000     2.000000    50.811753

# %%
plt.figure(figsize = (8,6))
sns.histplot(obesity['Weight'], kde = True)
plt.title('Distribution plot of Weight', fontweight = 'bold');

# %%
plt.figure(figsize = (8,6))
sns.histplot(obesity['Height'], kde = True)
plt.title('Distribution plot of Height', fontweight = 'bold');

# %%
plt.figure(figsize = (8,6))
sns.histplot(obesity['TUE'], kde = True)
plt.title('Distribution plot of Time spent on Technology (TUE)', fontweight = 'bold');

# %%
plt.figure(figsize = (8,6))
sns.histplot(obesity['FAF'], kde = True)
plt.title('Distribution plot of Physical Activity Frequency', fontweight = 'bold');

# %%
plt.figure(figsize = (8,6))
sns.histplot(obesity['CH2O'], kde = True)
plt.title('Distribution plot of Water Consumption', fontweight = 'bold');

# %%
plt.figure(figsize = (8,6))
sns.histplot(obesity['BMI'], kde = True)
plt.title('Distribution plot of Body Mass Index', fontweight = 'bold');

# %% [markdown]
# #### Univariate Data Analysis Discussion
#
# As observed from the BMI plot, although the data is widely spread along the axis, the most index is at 26 and 17, having it’s mean value at 29. The majority of the index at about 95% is concentrated at the index ranging from 20 – 45. The plot is slightly skewed to the right and there does not seem to be any outlier.
#
# As observed from the Age plot, although the data is not spread along the axis but concentrated at the age range of 14 - 25, having it’s mean value at 24. The plot is skewed to the right.
#
# As observed from the Weight plot, the data is widely spread along the axis, the least count weight are observed at 140kg to 173kg. The majority of the weights at about 90% is concentrated at the index ranging from 40kg to 120kg. The plot is slightly skewed to the right and there does not seem to be any outlier. The Height data is evenly distributed with a slight imbalance  and most height at 1.6m to 1.8m

# %% [markdown]
# ### Bivariate analysis
#
# Bivariate analysis were as well carried out using the boxplot, jointplot, regplot, and lineplot. These helped in understanding the form, strength and dependence  of the relationship between two selected variables.
#
#
# #### Bivariate Data Analysis Result and Discussion

# %%
sns.barplot(x = 'Gender', y = 'BMI', data = obesity, estimator = np.mean)
plt.title('Barplot of the mean BMI of both Genders', fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Barplot of the mean BMI of both Genders')

# %%
sns.boxplot(x='Gender', y = 'BMI', data = obesity)
plt.title('Five point summary of the BMI based on Gender', fontweight = 'bold');

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x='Gender', y = 'BMI', data = obesity, hue = 'family_history_with_overweight')
plt.title('Boxplot of BMI vs Gender with respect to Family History with Overweight', fontweight = 'bold');

# %%
plt.figure(figsize = (12,10))
sns.boxplot(x='MTRANS', y = 'BMI', data = obesity)
plt.title('Boxplot of Body Mass Index vs the Means of Transportation', fontweight = 'bold');

# %%
plt.figure(figsize = (12,10))
sns.boxplot(x='Gender', y = 'BMI', data = obesity, hue = 'MTRANS')
plt.title('Boxplot of BMI vs Gender with respect to Means of Transportation', fontweight = 'bold', fontsize = 15);

# %%
plt.figure(figsize = (12,10))
sns.jointplot(x='FAF', y = 'BMI', data = obesity, kind = 'reg')

# %%
plt.figure(figsize = (12,10))
sns.boxplot(x='CAEC', y = 'BMI', data = obesity)
# Out:
# <AxesSubplot:xlabel='CAEC', ylabel='BMI'>

# %% [markdown]
# As observed from the plots above, there is higher body mass index in female than in male, but both gender has higher BMI as result of overweight in the family history. There is higher body mass index for those that opted for automobile and public transportation as means of transportation, which can be as a result of less physical activity done relating to exercise.

# %%
plt.figure(figsize = (12,10))
sns.boxplot(x='CAEC', y = 'BMI', data = obesity, hue = 'FAVC')
plt.title('Boxplot of BMI vs Consumption of food between meals (CAEC) with respect to Frequent consumption of high caloric food (FAVC)', fontweight = 'bold', fontsize = 15);

# %% [markdown]
# The figure above explains the relationship between the frequency in consuming high caloric food and also eating between meals.  It can  be seen that those that  eat high caloric food have higher BMI. There is higher BMI for those that consume high caloric food seldomly than those that do always. This can be a result of the activities they are involved in and how often the monitor their calories level.

# %%
plt.figure(figsize = (12,10))
sns.lmplot(x='FCVC', y = 'BMI', data = obesity)
plt.title('Line plot of BMI against the Frequency of Vegetable Consumption', fontweight = 'bold', fontsize=12);

# %%
plt.figure(figsize = (12,10))
sns.lmplot(x='FCVC', y = 'BMI', data = obesity, hue = 'Gender')
plt.title('Line plot of BMI against the Frequency of Vegetable Consumption per Gender', fontweight = 'bold', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Line plot of BMI against the Frequency of Vegetable Consumption per Gender')

# %% [markdown]
# The line plot above explains the relationship between the frequency of vegetable consumption and BMI, this is further compared between genders. It can be observed that an increase in the consumption result in an increase in the BMI and this higher in Females than in Male gender.

# %% [markdown]
# ### Multivariate Analysis
#
# Multivariate Analysis was done by; using the FacetGrid to visualize the distribution of multiple variables , and generating the correlation among the numerical and categorical (using the pivot table function) variables  and visualized on the heatmap and clustermap.
#
# #### Multivariate Data Analysis Result and Discussion

# %%
obesity
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS             NObesity        BMI
# 0             no  Public_Transportation        Normal_Weight  24.386526
# 1      Sometimes  Public_Transportation        Normal_Weight  24.238227
# 2     Frequently  Public_Transportation        Normal_Weight  23.765432
# 3     Frequently                Walking   Overweight_Level_I  26.851852
# 4      Sometimes  Public_Transportation  Overweight_Level_II  28.342381
# ...          ...                    ...                  ...        ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III  44.901475
# 2107   Sometimes  Public_Transportation     Obesity_Type_III  43.741923
# 2108   Sometimes  Public_Transportation     Obesity_Type_III  43.543817
# 2109   Sometimes  Public_Transportation     Obesity_Type_III  44.071535
# 2110   Sometimes  Public_Transportation     Obesity_Type_III  44.144338
#
# [2111 rows x 18 columns]

# %%
plt.figure(figsize = (12,10))
sns.heatmap(obesity.corr(method = 'pearson'), cmap = 'gnuplot_r', annot = True, fmt = '.2f');
plt.title('Heatmap of Numerical Variables of Obesity', fontweight = 'bold', fontsize=15);

# %% [markdown]
# The heatmap of the correlation showed a weak correlation between the all variables except the BMI and Weight which strongly correlates to each other.

# %%
sns.clustermap(obesity.corr(), cmap = 'gnuplot_r', standard_scale = 2)

# %%
plt.figure(figsize = (16,16))
g = sns.FacetGrid(obesity, row = 'SCC', col = 'MTRANS', hue = 'Gender')
g = g.map(plt.scatter, "FAF", 'BMI' )
plt.legend();

# %% [markdown]
# As previously highlighted concerning those opted for public transport and automobile, and how they have higher body mass index. It is interesting to check the extent of the BMI if factors such as regular physical activity  and monitoring of caloric consumption is included. It can be observed that with an increase in physical activity and constant monitoring of consumption, there is relatively lower BMI.

# %%
obesity_pivot=obesity.pivot_table(index ='FAVC',columns= 'SCC', values='Weight')

# %%
sns.heatmap(obesity_pivot, cmap='gnuplot_r', lw=3, annot = True, fmt = '.2f')
plt.title('Heatmap of the FAVC and SCC in terms of Weight', fontweight = 'bold', fontsize=12);

# %% [markdown]
# There is an obvious increase in the BMI for those that consumer vegetables frequently and no monitoring of caloric consumption as seen on the heatmap generated.

# %%
sns.lmplot(x ="Age", y = 'BMI', data = obesity,  hue = 'family_history_with_overweight')
plt.title('Line plot of BMI against Age per Family History', fontweight = 'bold', fontsize=12);

# %% [markdown]
# And as seen on the plot, the family with an history of overweight gave an higher value of BMI but there seem to be lower rate in the increase compared to the increase in age for families with history of overweight. This can be explained as a factor of consciousness of their history and hence a close monitoring was done on their consumptions and activity.

# %%
sns.jointplot(x ="Age", y = 'BMI', data = obesity, hue = 'Gender')
plt.title('Joint plot of BMI against Age per Gender', fontweight = 'bold', fontsize=12, loc = 'right');

# %%
sns.lmplot(x ="Age", y = 'BMI', data = obesity,hue = 'Gender')
plt.title('Line plot of BMI against Age  per Gender', fontweight = 'bold', fontsize=12);

# %% [markdown]
# In terms of Age and BMI, there is also an higher BMI in Female gender than in Male, Although both gave positive linear relationship to the BMI.

# %% [markdown]
# ### Normality Test
#
#
# The normality of the dependent variable was checked whether the sample data was drawn from a normally distributed population. This was actualized by importing the statsmodels library and performing the function qqplot as well as the Shapiro from the scipy library.

# %%
import statsmodels
from statsmodels.graphics.gofplots import qqplot
from scipy.stats import shapiro

# %%
stat, pvalue = shapiro(obesity['BMI'])
print('the statistics = %.3f, p-value = %.3f'%(stat, pvalue))
# Out:
# the statistics = 0.975, p-value = 0.000

# %%
qqplot(obesity['BMI'], line ='s')
plt.title('QQplot of BMI', fontweight = 'bold', fontsize=12);

# %% [markdown]
# The normality test showed that the BMI is not normally distributed as it deviates from the center of linearity  using the qqplot.

# %% [markdown]
# ### Correlation Test
#
#
# The linear correlation between the two numerical variables. Basically, the test was done between each independent numerical variable and the dependent variable (BMI). This helped to measure the strength and direction of the relationship between them. The pearsonr and spearmanr function from the scipy.stats library was used to execute this.

# %%
from scipy.stats import pearsonr, spearmanr

# %%
FCVC_coeff, FCVC_pvalue = pearsonr(obesity['FCVC'], obesity['BMI'])

# %%
FCVC_coeff, FCVC_pvalue
# Out:
# (0.2636508377835164, 6.633451047951952e-35)

# %%
Weight_coeff, Weight_pvalue = pearsonr(obesity['Weight'], obesity['BMI'])

# %%
Weight_coeff, Weight_pvalue
# Out:
# (0.9348057478001087, 0.0)

# %%
Age_coeff, Age_pvalue = pearsonr(obesity['Age'], obesity['BMI'])

# %%
Age_coeff, Age_pvalue
# Out:
# (0.2441631161217907, 5.0064672463805056e-30)

# %%
FAF_coeff, FAF_pvalue = pearsonr(obesity['FAF'], obesity['BMI'])

# %%
FAF_coeff, FAF_pvalue
# Out:
# (-0.17753731835430028, 2.0762908567056803e-16)

# %%
CH2O_coeff,CH2O_pvalue = pearsonr(obesity['CH2O'], obesity['BMI'])

# %%
CH2O_coeff,CH2O_pvalue
# Out:
# (0.14420028026170395, 2.8087782461755323e-11)

# %%
Height_coeff, Height_pvalue = pearsonr(obesity['Height'], obesity['BMI'])

# %%
Height_coeff, Height_pvalue
# Out:
# (0.13178454241888077, 1.2179627776070788e-09)

# %% [markdown]
# ### T -Test
#
#
# This statistical test were performed to carry out hypothesis testing and compare the mean of two-grouped categorical variables (Gender, family history, FAVC, SMOKE, SCC). This was executed using the researchpy library.

# %%
pip install researchpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: researchpy in c:\users\olaso\appdata\roaming\python\python39\site-packages (0.3.5)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from researchpy) (1.21.5)
# Requirement already satisfied: patsy in c:\programdata\anaconda3\lib\site-packages (from researchpy) (0.5.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from researchpy) (1.7.3)
# Requirement already satisfied: statsmodels in c:\programdata\anaconda3\lib\site-packages (from researchpy) (0.13.2)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from researchpy) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->researchpy) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->researchpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->researchpy) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\programdata\anaconda3\lib\site-packages (from statsmodels->researchpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels->researchpy) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import researchpy as rp

# %% [markdown]
# #### The Check for significance difference between

# %%
obesity
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS             NObesity        BMI
# 0             no  Public_Transportation        Normal_Weight  24.386526
# 1      Sometimes  Public_Transportation        Normal_Weight  24.238227
# 2     Frequently  Public_Transportation        Normal_Weight  23.765432
# 3     Frequently                Walking   Overweight_Level_I  26.851852
# 4      Sometimes  Public_Transportation  Overweight_Level_II  28.342381
# ...          ...                    ...                  ...        ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III  44.901475
# 2107   Sometimes  Public_Transportation     Obesity_Type_III  43.741923
# 2108   Sometimes  Public_Transportation     Obesity_Type_III  43.543817
# 2109   Sometimes  Public_Transportation     Obesity_Type_III  44.071535
# 2110   Sometimes  Public_Transportation     Obesity_Type_III  44.144338
#
# [2111 rows x 18 columns]

# %% [markdown]
# ### BMI and Gender T-test
# Ho: There is no significant difference between the BMI of the Male vs the Female
#
# H1: There is significant difference between the BMI of the Male vs the Female

# %%
male_total= obesity['BMI'][obesity['Gender']=='Male']
female_total= obesity['BMI'][obesity['Gender']=='Female']

# %%
print(np.mean(male_total))
print(np.mean(female_total))
# Out:
# 29.280377404164767
# 30.130002026448054

# %%
gender_summary, gender_test = rp.ttest(group1 =male_total,group1_name= 'Male_BMI',
         group2 =female_total, group2_name= 'Female_BMI')
# Out:
# C:\Users\olaso\AppData\Roaming\Python\Python39\site-packages\researchpy\ttest.py:38: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
gender_summary
# Out:
#      Variable       N       Mean        SD        SE  95% Conf.   Interval
# 0    Male_BMI  1068.0  29.280377  6.346875  0.194211  28.899298  29.661457
# 1  Female_BMI  1043.0  30.130002  9.399448  0.291045  29.558901  30.701103
# 2    combined  2111.0  29.700159  8.011337  0.174366  29.358212  30.042105

# %%
gender_test
# Out:
#                       Independent t-test    results
# 0  Difference (Male_BMI - Female_BMI) =     -0.8496
# 1                  Degrees of freedom =   2109.0000
# 2                                   t =     -2.4390
# 3               Two side test p value =      0.0148
# 4              Difference < 0 p value =      0.0074
# 5              Difference > 0 p value =      0.9926
# 6                           Cohen's d =     -0.1062
# 7                           Hedge's g =     -0.1061
# 8                      Glass's delta1 =     -0.1339
# 9                    Point-Biserial r =     -0.0530

# %% [markdown]
# There is a significant difference between the mean as the pvalue is less than 0.05, hence we reject the null hypothesis and accept the alternative hypothesis.

# %% [markdown]
# ### BMI and Family History T-test
# Ho: There is no significant difference between the BMI of the Family History of Overweight vs the No Family History with Overweight
#
# H1: There is significant difference between the BMI of the Family History of Overweight vs the No Family History with Overweight

# %%
familyhistory_total= obesity['BMI'][obesity['family_history_with_overweight']=='yes']
nofamilyhistory_total= obesity['BMI'][obesity['family_history_with_overweight']=='no']

# %%
print(np.mean(familyhistory_total))
print(np.mean(nofamilyhistory_total))
# Out:
# 31.529168764517816
# 21.50049323032578

# %%
family_summary, family_test = rp.ttest(group1 =familyhistory_total,group1_name= 'FHistory_BMI',
         group2 =nofamilyhistory_total, group2_name= 'NFHistory_BMI')
# Out:
# C:\Users\olaso\AppData\Roaming\Python\Python39\site-packages\researchpy\ttest.py:38: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
family_summary
# Out:
#         Variable       N       Mean        SD        SE  95% Conf.   Interval
# 0   FHistory_BMI  1726.0  31.529169  7.497075  0.180456  31.175233  31.883104
# 1  NFHistory_BMI   385.0  21.500493  4.210658  0.214595  21.078565  21.922422
# 2       combined  2111.0  29.700159  8.011337  0.174366  29.358212  30.042105

# %%
family_test
# Out:
#                              Independent t-test    results
# 0  Difference (FHistory_BMI - NFHistory_BMI) =     10.0287
# 1                         Degrees of freedom =   2109.0000
# 2                                          t =     25.3668
# 3                      Two side test p value =      0.0000
# 4                     Difference < 0 p value =      1.0000
# 5                     Difference > 0 p value =      0.0000
# 6                                  Cohen's d =      1.4297
# 7                                  Hedge's g =      1.4292
# 8                             Glass's delta1 =      1.3377
# 9                           Point-Biserial r =      0.4835

# %% [markdown]
# There is a significant difference between the mean as the pvalue is less than 0.05, hence we reject the null hypothesis and accept the alternative hypothesis.

# %% [markdown]
# ### BMI and SMOKE T-test
# Ho: There is no significant difference between the BMI of the Smokers vs Non-smokers
#
# H1: There is significant difference between the BMI of the Smokers vs Non-smokers

# %%
smokers_total= obesity['BMI'][obesity['SMOKE']=='yes']
nonsmokers_total= obesity['BMI'][obesity['SMOKE']=='no']

# %%
print(np.mean(smokers_total))
print(np.mean(nonsmokers_total))
# Out:
# 29.655198324602555
# 29.701115846613785

# %%
smoke_summary, smoke_test = rp.ttest(group1 = smokers_total,group1_name = 'Smokers_BMI',
         group2 =nonsmokers_total, group2_name= 'NonSmokers_BMI')
# Out:
# C:\Users\olaso\AppData\Roaming\Python\Python39\site-packages\researchpy\ttest.py:38: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
smoke_summary
# Out:
#          Variable       N       Mean        SD        SE  95% Conf.   Interval
# 0     Smokers_BMI    44.0  29.655198  6.596156  0.994408  27.649784  31.660613
# 1  NonSmokers_BMI  2067.0  29.701116  8.040074  0.176844  29.354305  30.047926
# 2        combined  2111.0  29.700159  8.011337  0.174366  29.358212  30.042105

# %%
smoke_test
# Out:
#                              Independent t-test    results
# 0  Difference (Smokers_BMI - NonSmokers_BMI) =     -0.0459
# 1                         Degrees of freedom =   2109.0000
# 2                                          t =     -0.0376
# 3                      Two side test p value =      0.9700
# 4                     Difference < 0 p value =      0.4850
# 5                     Difference > 0 p value =      0.5150
# 6                                  Cohen's d =     -0.0057
# 7                                  Hedge's g =     -0.0057
# 8                             Glass's delta1 =     -0.0070
# 9                           Point-Biserial r =     -0.0008

# %% [markdown]
# There is no significant difference between the mean as the p value is greater than 0.05, hence we accept the null hypothesis and reject the alternative hypothesis.

# %% [markdown]
# ### BMI and SCC -Calories Monitoring T-test
# Ho: There is no significant difference between the BMI of those that do not monitor their calories consumption vs monitor their calories consumption
#
# H1: There is significant difference between the BMI of those that do not monitor their calories consumption vs monitor their calories consumption

# %%
noSCC_total= obesity['BMI'][obesity['SCC']=='no']
SCC_total= obesity['BMI'][obesity['SCC']=='yes']

# %%
print(np.mean(noSCC_total))
print(np.mean(SCC_total))
# Out:
# 30.02233460877328
# 22.937822339114934

# %%
SCC_summary, SCC_test = rp.ttest(group1 = noSCC_total,group1_name= 'noSCC_BMI',
         group2 =SCC_total, group2_name= 'SCC_BMI')
# Out:
# C:\Users\olaso\AppData\Roaming\Python\Python39\site-packages\researchpy\ttest.py:38: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
SCC_summary
# Out:
#     Variable       N       Mean        SD        SE  95% Conf.   Interval
# 0  noSCC_BMI  2015.0  30.022335  8.011681  0.178479  29.672313  30.372357
# 1    SCC_BMI    96.0  22.937822  4.040784  0.412411  22.119083  23.756561
# 2   combined  2111.0  29.700159  8.011337  0.174366  29.358212  30.042105

# %%
SCC_test
# Out:
#                     Independent t-test    results
# 0  Difference (noSCC_BMI - SCC_BMI) =      7.0845
# 1                Degrees of freedom =   2109.0000
# 2                                 t =      8.6106
# 3             Two side test p value =      0.0000
# 4            Difference < 0 p value =      1.0000
# 5            Difference > 0 p value =      0.0000
# 6                         Cohen's d =      0.8995
# 7                         Hedge's g =      0.8992
# 8                    Glass's delta1 =      0.8843
# 9                  Point-Biserial r =      0.1843

# %% [markdown]
# There is a significant difference between the mean as the pvalue is less than 0.05, hence we reject the null hypothesis and accept the alternative hypothesis.

# %% [markdown]
# ### BMI and FAVC T-test
# Ho: There is no significant difference between the BMI of Frequency of High Calories Consumption and No Frequency of High Calories Cosumption
#
# H1: There is significant difference between the BMI of Frequency of High Calories Consumption and No Frequency of High Calories Cosumption

# %%
FAVC_total= obesity['BMI'][obesity['FAVC']=='yes']
noFAVC_total= obesity['BMI'][obesity['FAVC']=='no']

# %%
print(np.mean(FAVC_total))
print(np.mean(noFAVC_total))
# Out:
# 30.41438375518261
# 24.260388139030347

# %%
FAVC_summary, FAVC_test = rp.ttest(group1 = FAVC_total,group1_name= 'FAVC_BMI',
         group2 =noFAVC_total, group2_name= 'noFAVC_BMI')
# Out:
# C:\Users\olaso\AppData\Roaming\Python\Python39\site-packages\researchpy\ttest.py:38: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
FAVC_summary
# Out:
#      Variable       N       Mean        SD        SE  95% Conf.   Interval
# 0    FAVC_BMI  1866.0  30.414384  8.052005  0.186401  30.048807  30.779960
# 1  noFAVC_BMI   245.0  24.260388  5.083094  0.324747  23.620723  24.900053
# 2    combined  2111.0  29.700159  8.011337  0.174366  29.358212  30.042105

# %%
FAVC_test
# Out:
#                       Independent t-test    results
# 0  Difference (FAVC_BMI - noFAVC_BMI) =      6.1540
# 1                  Degrees of freedom =   2109.0000
# 2                                   t =     11.6603
# 3               Two side test p value =      0.0000
# 4              Difference < 0 p value =      1.0000
# 5              Difference > 0 p value =      0.0000
# 6                           Cohen's d =      0.7923
# 7                           Hedge's g =      0.7921
# 8                      Glass's delta1 =      0.7643
# 9                    Point-Biserial r =      0.2461

# %% [markdown]
# There is a significant difference between the mean as the pvalue is less than 0.05, hence we reject the null hypothesis and accept the alternative hypothesis.

# %% [markdown]
# ## Anova Test
#
#
# For categorical variable with more than two groups, the anova test was performed to check if there is a significant difference in the mean values of the groups . This was done for the variables CAEC, CALC and MTRANS using the statsmodels.api library, followed by executing the functions ols and .stats.anova_lm.  The corresponding pvalues and F values were obtained.

# %% [markdown]
# #### Anova Test for the CAEC, CALC, and MTRANS

# %% [markdown]
# CAEC
#
# $$
# Ho: \mu_1 = \mu_2 = \mu_3 = \mu_4
# H1: \mu_1 \= \mu_2 \= \mu_3 \= \mu_4
# $$
#
# CALC
#
# $$
# Ho: \mu_1 = \mu_2 = \mu_3 = \mu_4
# H1: \mu_1 \= \mu_2 \= \mu_3 \= \mu_4
# $$
#
# MTRANS
#
# $$
# Ho: \mu_1 = \mu_2 = \mu_3 = \mu_4 = \mu_5
# H1: \mu_1 \= \mu_2 \= \mu_3 \= \mu_4 \= \mu_5
# $$

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.graphics.factorplots import interaction_plot

# %%
CAEC_model = ols('BMI ~ C(CAEC)', data = obesity).fit()

# %%
CAEC_anova_model =sm.stats.anova_lm(CAEC_model)

# %%
CAEC_anova_model
# Out:
#               df         sum_sq      mean_sq          F        PR(>F)
# C(CAEC)      3.0   25125.429886  8375.143295  159.98927  2.015034e-93
# Residual  2107.0  110297.565327    52.348156        NaN           NaN

# %% [markdown]
# There is a significant difference between the mean as the pvalue is less than 0.05, hence we reject the null hypothesis and accept the alternative hypothesis.

# %%
CALC_model = ols('BMI ~ C(CALC)', data = obesity).fit()

# %%
CALC_anova_model =sm.stats.anova_lm(CALC_model)

# %%
CALC_anova_model
# Out:
#               df         sum_sq      mean_sq          F        PR(>F)
# C(CALC)      3.0    7537.668182  2512.556061  41.396114  5.467884e-26
# Residual  2107.0  127885.327031    60.695457        NaN           NaN

# %% [markdown]
# There is a significant difference between the mean as the pvalue is less than 0.05, hence we reject the null hypothesis and accept the alternative hypothesis.

# %%
MTRANS_model = ols('BMI ~ C(MTRANS)', data = obesity).fit()

# %%
MTRANS_anova_model =sm.stats.anova_lm(MTRANS_model)

# %%
MTRANS_anova_model
# Out:
#                df         sum_sq     mean_sq         F        PR(>F)
# C(MTRANS)     4.0    2740.645337  685.161334  10.87522  9.968810e-09
# Residual   2106.0  132682.349877   63.002065       NaN           NaN

# %% [markdown]
# There is a significant difference between the mean as the pvalue is less than 0.05, hence we reject the null hypothesis and accept the alternative hypothesis.
# Although there is less significance in MTRANS and CALC compared to the CAEC, judging from the value of the Fvalue.

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Regression Problems
#
#
# Based on the data given, there are both categorical and numerical attributes which would permit to perform both regression and classification algorithms to predict the output of the dependent variables.
#
# The Regression Model
#
# Y = a + b1X1 + b2X2 + b3X3 + b4X4 + b5X5 + b6X6 + b7X7  ...... + e
#
#
# Regression model was generated by making the machine to learn the relationship between the numerical variable  against the output variables. The following steps were taken, namely;
#
#
# 1.	Splitting of the data into the X and Y variables.
#
# 2.	Splitting the variables into the train and test variable using the train_test_split function from the sklearn.model_selection library.
#
# 3.	Instantiating the model using the LinearRegression function from the sklearn.linear_model library
#
# 4.	Fitting the model using the LinearRegression.fit function.
#
# 5.	Generating the predictions by using the LinearRegression.predict function
#
# 6.	Calculating the residuals by subtracting the predictions from the tested dependent variable.
#
# 7.	Plotting the distribution of the residual to check the uniform distribution.
#
# 8.	Evaluating the metrics of the model suing the metrics function from the sklearn library
#
# 9.	Generating the coefficients and the other values of the model.

# %%
### Splitting data into X and Y

y = obesity['BMI']

# %%
x = obesity[['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']]

# %%
obesity.describe().columns
# Out:
# Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE', 'BMI'], dtype='object')

# %%
## step 2 ( train:test = 70:30 or 80:20)

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=101)

# %%
X_train
# Out:
#             Age    Height      Weight      FCVC       NCP      CH2O       FAF  \
# 1402  37.441044  1.524293   76.202761  2.000000  2.994046  1.603549  1.335857
# 196   22.000000  1.750000   74.000000  2.000000  3.000000  2.000000  1.000000
# 1337  18.603496  1.681719   90.671871  1.524428  3.000000  1.383831  0.130417
# 1342  21.727380  1.783782  105.000276  2.044326  3.000000  2.358180  0.349371
# 7     22.000000  1.640000   53.000000  2.000000  3.000000  2.000000  3.000000
# ...         ...       ...         ...       ...       ...       ...       ...
# 599   18.000000  1.716691   51.149283  1.813234  3.000000  1.274815  0.520407
# 1599  20.184451  1.701284  104.578255  2.653721  1.265463  1.368457  0.218356
# 1361  18.000000  1.686904   90.004046  2.737149  3.000000  1.997195  1.352663
# 1547  31.755387  1.775416  121.204668  2.758394  3.000000  2.161303  0.428173
# 863   30.613586  1.645511   69.168978  2.000466  3.000000  1.131448  0.061366
#
#            TUE
# 1402  0.000000
# 196   2.000000
# 1337  1.000000
# 1342  0.000000
# 7     0.000000
# ...        ...
# 599   1.673584
# 1599  0.768071
# 1361  0.468483
# 1547  0.716327
# 863   0.000000
#
# [1477 rows x 8 columns]

# %%
## Instantiating the model

from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
### Fit the model

lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## The Regression Model
#
# Y = a + b1X1 + b2X2 + b3X3 + b4X4 + ...... + e

# %%
print("The regression coefficient of the following Predictors are; \n", lm.coef_)
# Out:
# The regression coefficient of the following Predictors are;
#  [ 1.37122184e-02 -3.25137061e+01  3.38602506e-01  1.20746901e-01
#   1.39199665e-01  5.81826135e-02 -1.02770022e-01  3.42593564e-02]

# %%
### Step5


prediction = lm.predict(X_test)

# %%
#ResiduaL
diff_actaulpredicted = y_test - prediction
diff_actaulpredicted
sns.histplot(diff_actaulpredicted, kde = True)
plt.title( 'The Residual Plot of the Model', fontweight = 'bold', fontsize = 15);

# %%
prediction
# Out:
# array([25.52295176, 22.27636362, 38.23288042, 32.56823638, 47.87592527,
#        36.87651259, 34.46747686, 28.23155238, 26.21764237, 27.37719584,
#        28.56891832, 30.54953399, 35.71901917, 19.44071617, 43.99583478,
#        36.38240472, 29.37465103, 26.65615616, 26.4429014 , 28.33668477,
#        28.799313  , 44.1547846 , 27.93358669, 37.38836803, 36.69075126,
#        26.24109728, 21.29261373, 44.29065032, 26.44639519, 26.07400432,
#        20.39251281, 28.50214375, 31.51402579, 32.07327806, 32.71676196,
#        23.91821725, 25.83019352, 27.70544283, 31.37685024, 43.98395072,
#        19.07389405, 31.5764335 , 40.57146927, 16.71083897, 39.51405961,
#        37.19438204, 18.49955025, 16.93456732, 37.25853044, 28.19822246,
#        31.11584526, 19.93495812, 37.40424291, 36.89295767, 40.41602519,
#        34.92684455, 27.53202789, 44.62708743, 39.3600556 , 24.54275932,
#        33.17122701, 20.95917775, 21.03471994, 36.01486933, 32.43163728,
#        31.62305943, 36.61549962, 17.02814277, 30.56786493, 32.05690896,
#        38.99327367, 22.35930111, 27.3674158 , 36.21438833, 31.51495481,
#        36.96717356, 12.47270148, 32.08510035, 17.15325875, 15.91847434,
#        17.02388228, 37.28139536, 27.65362978, 39.00520599, 22.18088829,
#        27.63537751, 38.14827239, 25.68619407, 51.61744181, 40.22922591,
#        26.07875333, 30.0985175 , 35.32689333, 17.44609597, 38.97356914,
#        32.20525431, 38.74761354, 25.91644949, 25.54299586, 39.56086801,
#        18.71250301, 24.72684136, 21.90736992, 16.27434926, 27.53591367,
#        20.32404732, 15.86954395, 30.83242712, 31.18862628, 26.99115919,
#        43.76170073, 31.72196002, 32.33933707, 44.2659535 , 26.64346759,
#        36.4919888 , 36.65924155, 33.71033582, 32.72337408, 28.91866863,
#        31.15863582, 38.30670547, 28.22096982, 37.48502391, 38.20564705,
#        17.67875354, 30.25650005, 32.37501572, 44.26093382, 25.09206625,
#        20.17291876, 27.26171857, 27.56374692, 22.12236661, 21.90559512,
#        36.23477584, 25.42650491, 29.54344122, 30.61425672, 24.25723397,
#        27.042328  , 32.47314987, 37.37743347, 40.41200111, 28.35485178,
#        22.78600787, 44.04764137, 36.80312786, 28.39125965, 29.30491544,
#        35.29013535, 43.81617783, 32.2638963 , 22.16262228, 25.23432985,
#        24.30270219, 29.38090167, 24.93379914, 36.11990721, 17.27751804,
#        26.77339781, 31.31668422, 31.63654375, 26.90809752, 19.43345887,
#        25.91992684, 32.97256523, 34.30257168, 32.75501299, 22.05936902,
#        33.84956375, 29.11474813, 20.58428094, 28.77829456, 26.81472859,
#        28.6440463 , 26.42221929, 29.74501288, 19.22149153, 27.77751465,
#        27.62611821, 24.77202625, 45.2839198 , 18.59820261, 27.16420183,
#        22.3629908 , 26.07249373, 35.849956  , 38.05088363, 24.15807441,
#        21.31514915, 19.8528009 , 27.63512609, 48.39698943, 37.72493656,
#        16.43551205, 18.22607167, 37.11982357, 40.25705923, 21.90486388,
#        25.3560416 , 22.1442454 , 12.9778014 , 24.33629716, 17.16116834,
#        32.8090908 , 28.35904334, 25.87283969, 28.77926456, 26.23555002,
#        25.71263348, 21.35954123, 26.54289289, 20.32404732, 28.06354644,
#        39.68760869, 38.53352794, 14.12049911, 23.6515159 , 28.11579322,
#        20.44933818, 27.66861733, 16.0680699 , 29.01401361, 27.55792277,
#        25.00405745, 29.46721807, 26.53934843, 38.13206736, 24.17866393,
#        37.13425319, 36.62880058, 24.88929978, 21.38931253, 26.87808684,
#        31.61806536, 30.58960388, 16.4234727 , 44.44707549, 35.45045585,
#        26.65043751, 26.7494813 , 25.40018677, 37.80911795, 17.28321811,
#        26.73347387, 36.91125956, 44.2358386 , 45.5212988 , 31.15578341,
#        48.95354833, 27.34214877, 26.44639519, 27.59566992, 35.35760967,
#        30.81440577, 27.57990267, 27.72996767, 26.45820819, 39.03495901,
#        31.81388087, 17.12741401, 25.79308014, 34.36436067, 27.47348299,
#        33.13976336, 19.41260308, 27.35130201, 36.12540118, 39.14183723,
#        37.23846982, 30.43277012, 18.96212878, 26.57567895, 30.64728608,
#        44.45653579, 25.63042135, 26.40629894, 31.22932355, 36.54450128,
#        47.82933003, 31.05382184, 25.26139251, 39.56029173, 36.42871605,
#        37.53758704, 16.10429752, 21.22723263, 39.3709766 , 22.12035695,
#        27.11694052, 37.0230231 , 17.13084731, 26.18553661, 27.94194185,
#        26.4478808 , 30.36255515, 31.17924475, 44.45245596, 42.57692841,
#        38.21094521, 38.11277493, 33.99162469, 33.25390176, 34.2831753 ,
#        17.03797195, 16.08318818, 28.0705147 , 21.71882063, 26.94453406,
#        24.74661263, 39.29359475, 24.67699696, 29.26070086, 28.23679461,
#        17.58829545, 31.71631057, 43.59904532, 27.0064292 , 25.83185026,
#        17.85778061, 18.70334676, 39.88856655, 39.16092305, 16.93966049,
#        38.90437407, 36.76568818, 44.54160926, 22.08707329, 25.86914214,
#        32.65789191, 35.42014957, 36.83329986, 40.74805121, 39.64173341,
#        31.15719932, 17.2876303 , 35.50629376, 15.68886693, 36.75159196,
#        32.02307532, 26.23481836, 36.97570363, 31.39195178, 38.03636514,
#        44.02742332, 21.6526665 , 25.66088617, 33.63107467, 35.83597225,
#        26.04343598, 50.1032729 , 23.95474966, 24.34668943, 17.00488846,
#        17.48920883, 37.03791816, 36.94009908, 28.97447107, 28.8987644 ,
#        26.0456282 , 31.94999941, 38.15945939, 16.31781938, 15.74432114,
#        37.18611002, 43.70780885, 32.49344423, 28.96106291, 28.33298257,
#        22.46695162, 39.10663014, 40.61288188, 37.78903874, 31.79858093,
#        27.26321417, 25.74649479, 25.86588343, 26.44639519, 24.87507378,
#        27.49768113, 17.61266664, 32.28882983, 38.82873724, 26.10018955,
#        39.34754612, 14.98548588, 27.15779983, 16.556427  , 22.13312892,
#        33.5390197 , 34.76422624, 38.67119866, 27.89276462, 26.03340062,
#        34.51837074, 27.67273043, 16.36834583, 17.84654413, 25.63399383,
#        28.36791273, 18.61778388, 17.16443002, 38.90850488, 23.68383038,
#        38.75404564, 31.40028484, 29.33378031, 28.56698335, 31.09163375,
#        40.45498987, 27.57486959, 35.07825797, 21.24467313, 27.78235523,
#        37.4021977 , 27.80922336, 36.05552895, 26.36509865, 25.18018683,
#        26.31559915, 20.05251626, 34.07361103, 18.91243325, 37.7316552 ,
#        24.16026709, 27.53619707, 40.72764413, 29.98130811, 32.59839081,
#        21.43964502, 38.98619057, 28.15097744, 26.78365859, 31.76685279,
#        21.58639088, 21.51313184, 22.3116189 , 19.51083382, 36.04743709,
#        43.85395655, 20.94085755, 44.92100903, 24.53425622, 15.19549023,
#        26.46508139, 21.53792475, 33.13945548, 35.89359039, 38.07423025,
#        37.56552227, 27.56195275, 22.17018947, 25.93349441, 36.91324553,
#        40.42351058, 18.94646743, 33.85279432, 30.08295062, 16.29649622,
#        37.4132171 , 24.40765608, 30.12887629, 27.19456879, 43.01431333,
#        44.18935942, 30.18686303, 38.91640968, 30.79067171, 20.19356245,
#        33.36899789, 26.35866564, 24.43204373, 23.27138505, 25.95599199,
#        36.878729  , 25.50900891, 38.1413281 , 26.806522  , 31.10287319,
#        42.80101441, 32.0808184 , 37.20864791, 28.65991766, 31.71953252,
#        21.41095691, 38.19559444, 25.01824026, 25.63739038, 23.90172602,
#        39.72721619, 38.81065582, 17.6728073 , 36.20028679, 30.72562726,
#        21.59915861, 24.23659977, 29.91612928, 25.462496  , 35.29673065,
#        15.50694867, 34.52484918, 17.69443009, 30.94766422, 31.05740125,
#        26.44639519, 17.2309396 , 25.69479862, 32.47354743, 24.42016271,
#        38.42504763, 21.17078943, 17.49923407, 17.44256575, 40.48210366,
#        16.74012158, 23.14327613, 42.24740665, 33.0913739 , 30.50619133,
#        25.6850263 , 29.20799535, 36.3439704 , 38.54413865, 37.99101408,
#        37.30129312, 38.27227802, 40.9334988 , 17.44269057, 44.44205977,
#        34.85895159, 26.07215154, 38.57684344, 34.01713149, 30.76788156,
#        26.02076423, 44.7149019 , 36.63018913, 32.54621442, 30.92129927,
#        30.95211047, 35.92143519, 25.00359489, 37.06349112, 36.93196369,
#        37.94386945, 20.48477433, 22.97342667, 31.11372949, 17.09632833,
#        23.65296399, 17.19450004, 25.19307284, 36.62646385, 32.01206662,
#        25.79966461, 36.57984675, 24.23374038, 27.81458951, 20.33628034,
#        34.35330741, 40.79340565, 31.67893161, 29.23455705, 31.33350345,
#        25.31789443, 31.66122453, 30.38380849, 36.44143141, 26.4326885 ,
#        29.27593896, 17.34328537, 27.91696412, 49.82138754, 27.39931781,
#        26.93401222, 40.29655543, 26.49292352, 26.84949749, 25.7024197 ,
#        42.75044211, 23.2125193 , 34.20495902, 25.26415018, 33.7378669 ,
#        25.05007122, 17.51107742, 28.4560843 , 17.42176558, 18.25882366,
#        38.07089955, 34.6366617 , 25.76229672, 39.1419555 , 33.6285661 ,
#        45.12927922, 25.71904012, 31.70338868, 17.30443782, 38.29798966,
#        26.91429854, 26.3214097 , 28.65922626, 40.40583298, 30.53232911,
#        36.09126611, 40.79467059, 35.87810858, 16.71053465, 31.29049795,
#        36.88076598, 38.63893695, 39.03952647, 26.27912567, 25.41205371,
#        29.07950193, 40.40731471, 33.96751488, 26.24727598, 37.54099145,
#        25.99545889, 27.18084126, 31.74964041, 26.61365199, 19.76399604,
#        28.53530318, 40.12623804, 25.74422825, 23.77512244, 40.85186548,
#        22.13403564, 44.63750457, 26.44639519, 25.8052534 ])

# %%
# Evaluation
from sklearn import metrics
## The lower the RMSE the higher the accuracy of the model

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_absolute_error(y_test, prediction)))
# Out:
# MAE: 0.5973352559387414
# MSE: 0.6302154703430548
# RMSE: 0.7728746702659761

# %% [markdown]
# The RMSE explains the higher accuracy of the model as there is lower value.

# %%
lm.intercept_
# Out:
# 54.67599570066156

# %%
coeff = pd.DataFrame(lm.coef_,X_test.columns, columns = ['Coefficients'])

# %%
coeff
# Out:
#         Coefficients
# Age         0.013712
# Height    -32.513706
# Weight      0.338603
# FCVC        0.120747
# NCP         0.139200
# CH2O        0.058183
# FAF        -0.102770
# TUE         0.034259

# %% [markdown]
# Hence, the BMI and consequentially the Obesity Level of a person can be predicted using this Model Equation
#
# ## BMI =  54.67 + 0.014.Age – 32.52.Height + 0.339.Weight + 0.121.FCVC + 0.139.NCP + 0.058.CH2O - 0.103.FAF + 0.034.TUE
#
# Where;
#
# * BMI: Body Mass Index
#
# * Frequency of consumption of vegetables(FCVC)
#
# * Number of main meals (NCP)
#
# * Consumption of water daily (CH20)
#
# * Physical activity frequency (FAF)
#
# * Time using technology devices (TUE)

# %%
## Conclusion

# %%
## Recommendation

# %% [markdown]
# ### Thanks for Checking
